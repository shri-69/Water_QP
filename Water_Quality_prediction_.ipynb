# %% [markdown]
# **### To install basic/necessary libraries**
#
# pip install pandas numpy matplotlib seaborn scikit-learn

# %%
# Import necessary libraries
import pandas as pd # data manipulation
import numpy as np # numerical python - linear algebra

from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9fc8accb-0cc1-4153-ab60-f634135e3921" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9fc8accb-0cc1-4153-ab60-f634135e3921">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# load the dataset
df = pd.read_csv('PB_All_2000_2021.csv', sep=';')
df
# Out:
#       id        date    NH4  BSK5  Suspended     O2    NO3    NO2     SO4  \
# 0      1  17.02.2000  0.330  2.77       12.0  12.30   9.50  0.057  154.00
# 1      1  11.05.2000  0.044  3.00       51.6  14.61  17.75  0.034  352.00
# 2      1  11.09.2000  0.032  2.10       24.5   9.87  13.80  0.173  416.00
# 3      1  13.12.2000  0.170  2.23       35.6  12.40  17.13  0.099  275.20
# 4      1  02.03.2001  0.000  3.03       48.8  14.69  10.00  0.065  281.60
# ...   ..         ...    ...   ...        ...    ...    ...    ...     ...
# 2856  22  06.10.2020  0.046  2.69        3.6   8.28   3.80  0.038  160.00
# 2857  22  27.10.2020  0.000  1.52        0.5  11.26   0.56  0.031  147.20
# 2858  22  03.12.2020  0.034  0.29        0.8  11.09   2.58  0.042  209.92
# 2859  22  12.01.2021  0.000  2.10        0.0  14.31   3.94  0.034  121.60
# 2860  22  10.02.2021  0.000  1.78        0.0  14.30   6.30  0.033  134.40
#
#         PO4       CL
# 0     0.454   289.50
# 1     0.090  1792.00
# ...

# %%
df.info() # dataset info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2861 entries, 0 to 2860
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         2861 non-null   int64
#  1   date       2861 non-null   object
#  2   NH4        2858 non-null   float64
#  3   BSK5       2860 non-null   float64
#  4   Suspended  2845 non-null   float64
#  5   O2         2858 non-null   float64
#  6   NO3        2860 non-null   float64
#  7   NO2        2858 non-null   float64
#  8   SO4        2812 non-null   float64
#  9   PO4        2833 non-null   float64
#  10  CL         2812 non-null   float64
# dtypes: float64(9), int64(1), object(1)
# memory usage: 246.0+ KB

# %%
# rows and cols
df.shape
# Out:
# (2861, 11)

# %%
# Statistics of the data
df.describe().T
# Out:
#             count       mean         std   min      25%     50%       75%  \
# id         2861.0  12.397064    6.084226  1.00   8.0000  14.000  16.00000
# NH4        2858.0   0.758734    2.486247  0.00   0.0800   0.220   0.50000
# BSK5       2860.0   4.316182    2.973997  0.00   2.1600   3.800   5.80000
# Suspended  2845.0  12.931905   16.543097  0.00   6.0000  10.000  15.00000
# O2         2858.0   9.508902    4.428260  0.00   7.0925   8.995  11.52000
# NO3        2860.0   4.316846    6.881188  0.00   1.3900   2.800   5.58250
# NO2        2858.0   0.246128    2.182777  0.00   0.0300   0.059   0.12575
# SO4        2812.0  59.362313   96.582641  0.00  27.0525  37.800  64.64000
# PO4        2833.0   0.418626    0.771326  0.00   0.1300   0.270   0.47000
# CL         2812.0  93.731991  394.512184  0.02  26.8000  33.900  45.60750
#
#                 max
# id           22.000
# NH4          39.427
# BSK5         50.900
# Suspended   595.000
# O2           90.000
# NO3         133.400
# ...

# %%
# Missing values
df.isnull().sum()
# Out:
# id            0
# date          0
# NH4           3
# BSK5          1
# Suspended    16
# O2            3
# NO3           1
# NO2           3
# SO4          49
# PO4          28
# CL           49
# dtype: int64

# %%
# date is in object - date format
df['date'] = pd.to_datetime(df['date'], format='%d.%m.%Y')
df
# Out:
#       id       date    NH4  BSK5  Suspended     O2    NO3    NO2     SO4  \
# 0      1 2000-02-17  0.330  2.77       12.0  12.30   9.50  0.057  154.00
# 1      1 2000-05-11  0.044  3.00       51.6  14.61  17.75  0.034  352.00
# 2      1 2000-09-11  0.032  2.10       24.5   9.87  13.80  0.173  416.00
# 3      1 2000-12-13  0.170  2.23       35.6  12.40  17.13  0.099  275.20
# 4      1 2001-03-02  0.000  3.03       48.8  14.69  10.00  0.065  281.60
# ...   ..        ...    ...   ...        ...    ...    ...    ...     ...
# 2856  22 2020-10-06  0.046  2.69        3.6   8.28   3.80  0.038  160.00
# 2857  22 2020-10-27  0.000  1.52        0.5  11.26   0.56  0.031  147.20
# 2858  22 2020-12-03  0.034  0.29        0.8  11.09   2.58  0.042  209.92
# 2859  22 2021-01-12  0.000  2.10        0.0  14.31   3.94  0.034  121.60
# 2860  22 2021-02-10  0.000  1.78        0.0  14.30   6.30  0.033  134.40
#
#         PO4       CL
# 0     0.454   289.50
# 1     0.090  1792.00
# 2     0.200  2509.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2861 entries, 0 to 2860
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         2861 non-null   int64
#  1   date       2861 non-null   datetime64[ns]
#  2   NH4        2858 non-null   float64
#  3   BSK5       2860 non-null   float64
#  4   Suspended  2845 non-null   float64
#  5   O2         2858 non-null   float64
#  6   NO3        2860 non-null   float64
#  7   NO2        2858 non-null   float64
#  8   SO4        2812 non-null   float64
#  9   PO4        2833 non-null   float64
#  10  CL         2812 non-null   float64
# dtypes: datetime64[ns](1), float64(9), int64(1)
# memory usage: 246.0 KB

# %%
df = df.sort_values(by=['id', 'date'])
df.head()
# Out:
#    id       date    NH4  BSK5  Suspended     O2    NO3    NO2    SO4    PO4  \
# 0   1 2000-02-17  0.330  2.77       12.0  12.30   9.50  0.057  154.0  0.454
# 1   1 2000-05-11  0.044  3.00       51.6  14.61  17.75  0.034  352.0  0.090
# 2   1 2000-09-11  0.032  2.10       24.5   9.87  13.80  0.173  416.0  0.200
# 3   1 2000-12-13  0.170  2.23       35.6  12.40  17.13  0.099  275.2  0.377
# 4   1 2001-03-02  0.000  3.03       48.8  14.69  10.00  0.065  281.6  0.134
#
#        CL
# 0   289.5
# 1  1792.0
# 2  2509.0
# 3  1264.0
# 4  1462.0

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# %%
df.head()
# Out:
#    id       date    NH4  BSK5  Suspended     O2    NO3    NO2    SO4    PO4  \
# 0   1 2000-02-17  0.330  2.77       12.0  12.30   9.50  0.057  154.0  0.454
# 1   1 2000-05-11  0.044  3.00       51.6  14.61  17.75  0.034  352.0  0.090
# 2   1 2000-09-11  0.032  2.10       24.5   9.87  13.80  0.173  416.0  0.200
# 3   1 2000-12-13  0.170  2.23       35.6  12.40  17.13  0.099  275.2  0.377
# 4   1 2001-03-02  0.000  3.03       48.8  14.69  10.00  0.065  281.6  0.134
#
#        CL  year  month
# 0   289.5  2000      2
# 1  1792.0  2000      5
# 2  2509.0  2000      9
# 3  1264.0  2000     12
# 4  1462.0  2001      3

# %%
df.columns
# Out:
# Index(['id', 'date', 'NH4', 'BSK5', 'Suspended', 'O2', 'NO3', 'NO2', 'SO4',
#        'PO4', 'CL', 'year', 'month'],
#       dtype='object')

# %%
pollutants = ['O2', 'NO3', 'NO2', 'SO4',
       'PO4', 'CL']

# %% [markdown]
# ## Week 2 - 23 June 2025

# %%
# drop the missing values - dropna()
df = df.dropna(subset=pollutants)
df.head()
# Out:
#    id       date    NH4  BSK5  Suspended     O2    NO3    NO2    SO4    PO4  \
# 0   1 2000-02-17  0.330  2.77       12.0  12.30   9.50  0.057  154.0  0.454
# 1   1 2000-05-11  0.044  3.00       51.6  14.61  17.75  0.034  352.0  0.090
# 2   1 2000-09-11  0.032  2.10       24.5   9.87  13.80  0.173  416.0  0.200
# 3   1 2000-12-13  0.170  2.23       35.6  12.40  17.13  0.099  275.2  0.377
# 4   1 2001-03-02  0.000  3.03       48.8  14.69  10.00  0.065  281.6  0.134
#
#        CL  year  month
# 0   289.5  2000      2
# 1  1792.0  2000      5
# 2  2509.0  2000      9
# 3  1264.0  2000     12
# 4  1462.0  2001      3

# %%
df.isnull().sum()
# Out:
# id           0
# date         0
# NH4          2
# BSK5         0
# Suspended    2
# O2           0
# NO3          0
# NO2          0
# SO4          0
# PO4          0
# CL           0
# year         0
# month        0
# dtype: int64

# %%
# Feature and target selection - Feature - independent variable and Target dependent variable
X = df[['id', 'year']]
y = df[pollutants]

# %%
# Encoding - onehotencoder - 22 stations - 1 - 1
X_encoded = pd.get_dummies(X, columns=['id'], drop_first=True)

# %%
# Train, Test and Split
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42
)

# %%
# Train the model
model = MultiOutputRegressor(RandomForestRegressor(n_estimators=100, random_state=42))
model.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(random_state=42))

# %%
# Evaluate model
y_pred = model.predict(X_test)

# %%
print("Model Performance on the Test Data:")
for i, pollutant in enumerate(pollutants):
    print(f'{pollutant}:')
    print('   MSE:', mean_squared_error(y_test.iloc[:, i], y_pred[:, i]))
    print('   R2:', r2_score(y_test.iloc[:, i], y_pred[:, i]))
    print()
# Out:
# Model Performance on the Test Data:
# O2:
#    MSE: 22.21825046040189
#    R2: -0.01674257045728833
#
# NO3:
#    MSE: 18.153106746365886
#    R2: 0.5162032171220556
#
# NO2:
#    MSE: 10.607352172601502
#    R2: -78.42066512350873
#
# SO4:
#    MSE: 2412.139350033052
#    R2: 0.4118345603876148
#
# PO4:
#    MSE: 0.38496938017964155
#    R2: 0.3221189891402043
#
# CL:
#    MSE: 34882.81433245622
#    R2: 0.7357918194149974

# %%
station_id = '22'
year_input = 2024

input_data = pd.DataFrame({'year': [year_input], 'id': [station_id]})
input_encoded = pd.get_dummies(input_data, columns=['id'])

# Align with training feature columns
missing_cols = set(X_encoded.columns) - set(input_encoded.columns)
for col in missing_cols:
    input_encoded[col] = 0
input_encoded = input_encoded[X_encoded.columns]  # reorder columns

# Predict pollutants
predicted_pollutants = model.predict(input_encoded)[0]

print(f"\nPredicted pollutant levels for station '{station_id}' in {year_input}:")
for p, val in zip(pollutants, predicted_pollutants):
    print(f"  {p}: {val:.2f}")
# Out:
# Predicted pollutant levels for station '22' in 2024:
#   O2: 12.60
#   NO3: 6.90
#   NO2: 0.13
#   SO4: 143.08
#   PO4: 0.50
#   CL: 67.33

# %%
import joblib

joblib.dump(model, 'pollution_model.pkl')
joblib.dump(X_encoded.columns.tolist(), "model_columns.pkl")
print('Model and cols structure are saved!')
# Out:
# Model and cols structure are saved!

# %% [markdown]
# ## MY IMPROVISATIONS

# %%
print(df.columns.tolist())
# Out:
# ['id', 'date', 'NH4', 'BSK5', 'Suspended', 'O2', 'NO3', 'NO2', 'SO4', 'PO4', 'CL', 'year', 'month']

# %%
df['NH4_BSK5'] = df['NH4'] * df['BSK5']

# %%
df['NO3_SO4'] = df['NO3'] * df['SO4']

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import PolynomialFeatures

# Fill NaNs with mean (or median)
imputer = SimpleImputer(strategy='mean')
imputed_data = imputer.fit_transform(df[['NH4', 'BSK5', 'SO4']])

# Now create interaction terms
poly = PolynomialFeatures(degree=2, interaction_only=True, include_bias=False)
interaction_features = poly.fit_transform(imputed_data)

# %%
df['month'] = pd.to_datetime(df['date']).dt.month
df['season'] = df['month'].apply(lambda x: 'summer' if x in [4,5,6] else
                                             'monsoon' if x in [7,8,9] else
                                             'winter' if x in [10,11,12] else
                                             'spring')

# %%
df = pd.get_dummies(df, columns=['season'])

# %%
import numpy as np

locations = ['ZoneA', 'ZoneB', 'ZoneC']
df['location'] = np.random.choice(locations, size=len(df))

# %%
df = pd.get_dummies(df, columns=['location'])

# %%
df['high_risk_period'] = df['season_monsoon']

# %%
df['NH4_monsoon'] = df['NH4'] * df['season_monsoon']

# %%
df['NH4_alert'] = (df['NH4'] > df['NH4'].quantile(0.95)).astype(int)

# %%
df['total_nitrogen'] = df['NH4'] + df['NO3'] + df['NO2']

# %%
import numpy as np

# Create synthetic zones
zones = ['ZoneA', 'ZoneB', 'ZoneC']
df['region'] = np.random.choice(zones, size=len(df))

# %%
df['is_industrial'] = df['region'].apply(lambda x: 1 if x in ['ZoneA'] else 0)

# %%
import plotly.express as px

# Dummy coordinates for demonstration
df['lat'] = np.random.uniform(21.0, 23.0, len(df))
df['lon'] = np.random.uniform(75.0, 77.0, len(df))

fig = px.scatter_mapbox(df, lat='lat', lon='lon', color='NH4',
                        mapbox_style='carto-positron', zoom=5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
features = ['NH4', 'BSK5', 'SO4', 'is_industrial', 'season_summer', 'NH4_BSK5', 'NO3_SO4']
X = df[features]

# %%
# Example: average pollutant levels by region
region_summary = df.groupby('region')[['NH4', 'O2', 'NO3']].mean()
print(region_summary)
# Out:
#              NH4        O2       NO3
# region
# ZoneA   0.663874  9.433046  4.287788
# ZoneB   0.653327  9.537937  4.311181
# ZoneC   0.587513  9.668879  4.443628

# %%
import seaborn as sns
sns.barplot(data=region_summary.reset_index(), x='region', y='NH4')
# Out:
# <Axes: xlabel='region', ylabel='NH4'>

# %%
df['NH4_risk'] = df['NH4'].apply(lambda x: 'High' if x > 10 else 'Normal')

# %%
sns.countplot(data=df, x='season_monsoon', hue='NH4_risk')
# Out:
# <Axes: xlabel='season_monsoon', ylabel='count'>
